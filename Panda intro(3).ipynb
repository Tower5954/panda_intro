# %%
import pandas as pd

# %%
car_sales = pd.read_csv('car_sales_new.csv')

# %%
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price  Seats  \
# 0           0  toyota  White         150043      4   4000    5.0
# 1           1   honda    Red          87899      4   5000    5.0
# 2           2  toyota   Blue          32549      3   7000    5.0
# 3           3     bmw  Black          11179      5  22000    5.0
# 4           4  nissan  White         213095      4   3500    5.0
# 5           5  toyota  Green          99213      4   4500    5.0
# 6           6   honda   Blue          45698      4   7500    5.0
# 7           7   honda   Blue          54738      4   7000    5.0
# 8           8  toyota  White          60000      4   6250    5.0
# 9           9  nissan  White          31600      4   9700    5.0
#
#    Fuel per 100KM  Total fuel used (L)  number of wheels  Passed MOT
# 0             7.5            11253.225                 4        True
# 1             9.2             8086.708                 4        True
# 2             5.0             1627.450                 4        True
# 3             9.6             1073.184                 4        True
# 4             8.7            18539.265                 4        True
# 5             3.0             2976.390                 4        True
# 6             8.6             3930.028                 4        True
# 7             6.8             3722.184                 4        True
# 8             7.4             4440.000                 4        True
# 9             7.9             2496.400                 4        True

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price  Seats  \
# 2           2  toyota   Blue          32549      3   7000    5.0
# 4           4  nissan  White         213095      4   3500    5.0
# 7           7   honda   Blue          54738      4   7000    5.0
# 0           0  toyota  White         150043      4   4000    5.0
# 6           6   honda   Blue          45698      4   7500    5.0
# 3           3     bmw  Black          11179      5  22000    5.0
# 8           8  toyota  White          60000      4   6250    5.0
# 1           1   honda    Red          87899      4   5000    5.0
# 5           5  toyota  Green          99213      4   4500    5.0
# 9           9  nissan  White          31600      4   9700    5.0
#
#    Fuel per 100KM  Total fuel used (L)  number of wheels  Passed MOT
# 2             5.0             1627.450                 4        True
# 4             8.7            18539.265                 4        True
# 7             6.8             3722.184                 4        True
# 0             7.5            11253.225                 4        True
# 6             8.6             3930.028                 4        True
# 3             9.6             1073.184                 4        True
# 8             7.4             4440.000                 4        True
# 1             9.2             8086.708                 4        True
# 5             3.0             2976.390                 4        True
# 9             7.9             2496.400                 4        True

# %%
car_sales_shuffled
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price  Seats  \
# 2           2  toyota   Blue          32549      3   7000    5.0
# 4           4  nissan  White         213095      4   3500    5.0
# 7           7   honda   Blue          54738      4   7000    5.0
# 0           0  toyota  White         150043      4   4000    5.0
# 6           6   honda   Blue          45698      4   7500    5.0
# 3           3     bmw  Black          11179      5  22000    5.0
# 8           8  toyota  White          60000      4   6250    5.0
# 1           1   honda    Red          87899      4   5000    5.0
# 5           5  toyota  Green          99213      4   4500    5.0
# 9           9  nissan  White          31600      4   9700    5.0
#
#    Fuel per 100KM  Total fuel used (L)  number of wheels  Passed MOT
# 2             5.0             1627.450                 4        True
# 4             8.7            18539.265                 4        True
# 7             6.8             3722.184                 4        True
# 0             7.5            11253.225                 4        True
# 6             8.6             3930.028                 4        True
# 3             9.6             1073.184                 4        True
# 8             7.4             4440.000                 4        True
# 1             9.2             8086.708                 4        True
# 5             3.0             2976.390                 4        True
# 9             7.9             2496.400                 4        True

# %%
# Only select 20% of the data
car_sales_shuffled.sample(frac=0.2)
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price  Seats  \
# 4           4  nissan  White         213095      4   3500    5.0
# 6           6   honda   Blue          45698      4   7500    5.0
#
#    Fuel per 100KM  Total fuel used (L)  number of wheels  Passed MOT
# 4             8.7            18539.265                 4        True
# 6             8.6             3930.028                 4        True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price  Seats  \
# 0           2  toyota   Blue          32549      3   7000    5.0
# 1           4  nissan  White         213095      4   3500    5.0
# 2           7   honda   Blue          54738      4   7000    5.0
# 3           0  toyota  White         150043      4   4000    5.0
# 4           6   honda   Blue          45698      4   7500    5.0
# 5           3     bmw  Black          11179      5  22000    5.0
# 6           8  toyota  White          60000      4   6250    5.0
# 7           1   honda    Red          87899      4   5000    5.0
# 8           5  toyota  Green          99213      4   4500    5.0
# 9           9  nissan  White          31600      4   9700    5.0
#
#    Fuel per 100KM  Total fuel used (L)  number of wheels  Passed MOT
# 0             5.0             1627.450                 4        True
# 1             8.7            18539.265                 4        True
# 2             6.8             3722.184                 4        True
# 3             7.5            11253.225                 4        True
# 4             8.6             3930.028                 4        True
# 5             9.6             1073.184                 4        True
# 6             7.4             4440.000                 4        True
# 7             9.2             8086.708                 4        True
# 8             3.0             2976.390                 4        True
# 9             7.9             2496.400                 4        True

# %%
car_sales_shuffled.reset_index(drop=True)
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price  Seats  \
# 0           2  toyota   Blue          32549      3   7000    5.0
# 1           4  nissan  White         213095      4   3500    5.0
# 2           7   honda   Blue          54738      4   7000    5.0
# 3           0  toyota  White         150043      4   4000    5.0
# 4           6   honda   Blue          45698      4   7500    5.0
# 5           3     bmw  Black          11179      5  22000    5.0
# 6           8  toyota  White          60000      4   6250    5.0
# 7           1   honda    Red          87899      4   5000    5.0
# 8           5  toyota  Green          99213      4   4500    5.0
# 9           9  nissan  White          31600      4   9700    5.0
#
#    Fuel per 100KM  Total fuel used (L)  number of wheels  Passed MOT
# 0             5.0             1627.450                 4        True
# 1             8.7            18539.265                 4        True
# 2             6.8             3722.184                 4        True
# 3             7.5            11253.225                 4        True
# 4             8.6             3930.028                 4        True
# 5             9.6             1073.184                 4        True
# 6             7.4             4440.000                 4        True
# 7             9.2             8086.708                 4        True
# 8             3.0             2976.390                 4        True
# 9             7.9             2496.400                 4        True

# %%
car_sales_shuffled.drop( 'Unnamed: 0', axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota   Blue          32549      3   7000    5.0             5.0
# 1  nissan  White         213095      4   3500    5.0             8.7
# 2   honda   Blue          54738      4   7000    5.0             6.8
# 3  toyota  White         150043      4   4000    5.0             7.5
# 4   honda   Blue          45698      4   7500    5.0             8.6
# 5     bmw  Black          11179      5  22000    5.0             9.6
# 6  toyota  White          60000      4   6250    5.0             7.4
# 7   honda    Red          87899      4   5000    5.0             9.2
# 8  toyota  Green          99213      4   4500    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             7.9
#
#    Total fuel used (L)  number of wheels  Passed MOT
# 0             1627.450                 4        True
# 1            18539.265                 4        True
# 2             3722.184                 4        True
# 3            11253.225                 4        True
# 4             3930.028                 4        True
# 5             1073.184                 4        True
# 6             4440.000                 4        True
# 7             8086.708                 4        True
# 8             2976.390                 4        True
# 9             2496.400                 4        True

# %%
car_sales = car_sales.drop( 'Unnamed: 0', axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             3.0
# 6   honda   Blue          45698      4   7500    5.0             8.6
# 7   honda   Blue          54738      4   7000    5.0             6.8
# 8  toyota  White          60000      4   6250    5.0             7.4
# 9  nissan  White          31600      4   9700    5.0             7.9
#
#    Total fuel used (L)  number of wheels  Passed MOT
# 0            11253.225                 4        True
# 1             8086.708                 4        True
# 2             1627.450                 4        True
# 3             1073.184                 4        True
# 4            18539.265                 4        True
# 5             2976.390                 4        True
# 6             3930.028                 4        True
# 7             3722.184                 4        True
# 8             4440.000                 4        True
# 9             2496.400                 4        True

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x:x / 1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   4000    5.0             7.5
# 1   honda    Red      54936.875      4   5000    5.0             9.2
# 2  toyota   Blue      20343.125      3   7000    5.0             5.0
# 3     bmw  Black       6986.875      5  22000    5.0             9.6
# 4  nissan  White     133184.375      4   3500    5.0             8.7
# 5  toyota  Green      62008.125      4   4500    5.0             3.0
# 6   honda   Blue      28561.250      4   7500    5.0             8.6
# 7   honda   Blue      34211.250      4   7000    5.0             6.8
# 8  toyota  White      37500.000      4   6250    5.0             7.4
# 9  nissan  White      19750.000      4   9700    5.0             7.9
#
#    Total fuel used (L)  number of wheels  Passed MOT
# 0            11253.225                 4        True
# 1             8086.708                 4        True
# 2             1627.450                 4        True
# 3             1073.184                 4        True
# 4            18539.265                 4        True
# 5             2976.390                 4        True
# 6             3930.028                 4        True
# 7             3722.184                 4        True
# 8             4440.000                 4        True
# 9             2496.400                 4        True
